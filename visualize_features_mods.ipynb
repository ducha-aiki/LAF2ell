# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from LAF import readMODS_ExtractFeaturesFile, visualize_LAFs,convertLAFs_to_A23format, readMODS_keypointsFile
import seaborn as sns

img_fname = '/home/old-ufo/Dropbox/Mik/graf/img1.png'

img = Image.open(img_fname).convert('RGB')
img = np.mean(np.array(img), axis = 2)


MODS_features = readMODS_keypointsFile('/home/old-ufo/dev/mods/wxbs-journal/build/k1.txt')
# Out:
# HessianAffine 2
# CAFFE 7333
# 128
# None 3127
# 0

# %%
LAFs2, descs2 = MODS_features['HessianAffine']['CAFFE']
visualize_LAFs(img, convertLAFs_to_A23format(LAFs2[0:2000,:]))
