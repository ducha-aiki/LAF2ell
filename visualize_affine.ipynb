# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from LAF import LAFs2ell, ells2LAFs, visualize_LAFs,convertLAFs_to_A23format
import seaborn as sns

img_fname = 'graf1.ppm'

img = Image.open(img_fname).convert('RGB')
img = np.mean(np.array(img), axis = 2)


ellipses2 = np.loadtxt('ell1.txt')
LAFs1 = np.loadtxt('lafs1.txt')

# %%
visualize_LAFs(img, LAFs1)
#Since LAFs are oriented and ellipses are not, we lose orientation here
visualize_LAFs(img, ells2LAFs(LAFs2ell(LAFs1)))

# %%
visualize_LAFs(img, ells2LAFs(ellipses2))

visualize_LAFs(img, ells2LAFs(LAFs2ell(ells2LAFs(ellipses2))))
